# %% [markdown]
# # Linear, Ridge, Lasso, and Elastic Net Regression
#
# The next step is to fit the data to a few different machine learning models and then tweak the hyperparameters to see what the best model is.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
# Bring in the data
# %store -r X_train
# %store -r X_test
# %store -r y_train
# %store -r y_test

# %% [markdown]
# ### Linear Regression
#
# First, I will try a vanilla linear regression.

# %%
# Fit the training data to the model.
model1 = LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Define a linear regression function that can output R squared and RMSE.
def lr_R2_RMSE():
    data = []
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    model_r2_train = model.score(X_train, y_train)
    model_r2_test = model.score(X_test, y_test)
    
    model_y_pred_train = model.predict(X_train)
    model_y_pred_test = model.predict(X_test)
    model_RMSE_train = np.sqrt(mean_squared_error(y_train, model_y_pred_train))
    model_RMSE_test = np.sqrt(mean_squared_error(y_test, model_y_pred_test))
    
    data.append(['Linear', 'NA', 'NA', model_r2_train, model_r2_test, model_RMSE_train, model_RMSE_test])
            
    table = pd.DataFrame(data, columns = ['Model', 'Alpha', 'L1 Ratio', 'Training R2', 'Test R2', 'Training RMSE', 'Test RMSE'])
    
    return table

# %%
linear_results = lr_R2_RMSE()
linear_results
# Out:
#     Model Alpha L1 Ratio  Training R2   Test R2  Training RMSE    Test RMSE
# 0  Linear    NA       NA     0.756279  0.734275    6055.905613  5978.637219

# %%
# View the coefficients of each term.
print(X_train.columns)
print(model1.coef_)
# Out:
# Index(['age', 'bmi', 'sex_male', 'smoker_yes', 'children_1', 'children_2',
#        'children_3', 'children_4', 'children_5', 'region_northwest',
#        'region_southeast', 'region_southwest'],
#       dtype='object')
# [11592.50671814 12004.15232447  -268.42233783 24067.87704993
#   -103.80379432  1311.19532811   682.03649306  2127.71041988
#   1057.26082258  -251.34733476  -855.07435369  -654.86702882]

# %% [markdown]
# Smoker is the largest predictor of charges, followed by age and bmi.

# %% [markdown]
# ### Ridge Regression
#
# Now, I will see if regularization helps improve the model and reduces overfitting.

# %%
# Define a ridge regression function that can take different values of alpha and output R squared and RMSE.
def ridge_R2_RMSE(alpha):
    data = []
    for a in alpha:
        model = Ridge(alpha=a)
        model.fit(X_train, y_train)
    
        model_r2_train = model.score(X_train, y_train)
        model_r2_test = model.score(X_test, y_test)
    
        model_y_pred_train = model.predict(X_train)
        model_y_pred_test = model.predict(X_test)
        model_RMSE_train = np.sqrt(mean_squared_error(y_train, model_y_pred_train))
        model_RMSE_test = np.sqrt(mean_squared_error(y_test, model_y_pred_test))
    
        data.append(['Ridge', a, 'NA', model_r2_train, model_r2_test, model_RMSE_train, model_RMSE_test])
            
    table = pd.DataFrame(data, columns = ['Model', 'Alpha','L1 Ratio','Training R2', 'Test R2', 'Training RMSE', 'Test RMSE'])
    
    return table

# %%
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
ridge_results = ridge_R2_RMSE(alpha)
ridge_results
# Out:
#    Model     Alpha L1 Ratio  Training R2   Test R2  Training RMSE  \
# 0  Ridge     0.001       NA     0.756279  0.734275    6055.905614
# 1  Ridge     0.010       NA     0.756279  0.734271    6055.905704
# 2  Ridge     0.100       NA     0.756278  0.734231    6055.914666
# 3  Ridge     1.000       NA     0.756210  0.733789    6056.768114
# 4  Ridge    10.000       NA     0.751457  0.726636    6115.524076
# 5  Ridge   100.000       NA     0.627399  0.605047    7487.802904
# 6  Ridge  1000.000       NA     0.188570  0.181750   11049.891353
#
#       Test RMSE
# 0   5978.642138
# 1   5978.686458
# 2   5979.134880
# 3   5984.108551
# 4   6063.969647
# 5   7288.848304
# 6  10491.291756

# %% [markdown]
# Ridge regression with alpha set to 0.001 performed the best. Performance is similar to the first linear regression.

# %% [markdown]
# ### Lasso Regression
#
# Now, I will try Lasso regression.

# %%
# Define a lasso regression function that can take different values of alpha and output R squared and RMSE.
def lasso_R2_RMSE(alpha):
    data = []
    for a in alpha:
        model = Lasso(alpha=a)
        model.fit(X_train, y_train)
    
        model_r2_train = model.score(X_train, y_train)
        model_r2_test = model.score(X_test, y_test)
    
        model_y_pred_train = model.predict(X_train)
        model_y_pred_test = model.predict(X_test)
        model_RMSE_train = np.sqrt(mean_squared_error(y_train, model_y_pred_train))
        model_RMSE_test = np.sqrt(mean_squared_error(y_test, model_y_pred_test))
    
        data.append(['Lasso', a, 'NA', model_r2_train, model_r2_test, model_RMSE_train, model_RMSE_test])
            
    table = pd.DataFrame(data, columns = ['Model', 'Alpha', 'L1 Ratio', 'Training R2', 'Test R2', 'Training RMSE', 'Test RMSE'])
    
    return table

# %%
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
lasso_results = lasso_R2_RMSE(alpha)
lasso_results
# Out:
#    Model     Alpha L1 Ratio  Training R2   Test R2  Training RMSE    Test RMSE
# 0  Lasso     0.001       NA     0.756279  0.734275    6055.905613  5978.638781
# 1  Lasso     0.010       NA     0.756279  0.734274    6055.905616  5978.652878
# 2  Lasso     0.100       NA     0.756279  0.734261    6055.905868  5978.793975
# 3  Lasso     1.000       NA     0.756277  0.734133    6055.931079  5980.231914
# 4  Lasso    10.000       NA     0.756074  0.732604    6058.449823  5997.408123
# 5  Lasso   100.000       NA     0.750835  0.721436    6123.164553  6121.367999
# 6  Lasso  1000.000       NA     0.616996  0.569830    7591.616079  7606.871530

# %% [markdown]
# Lasso regression with alpha set to 0.001 performed about the same as ridge regression.

# %% [markdown]
# ### Elastic Net Regression

# %% [markdown]
# Finally, I will try using elastic regression to see if results can be improved.

# %%
# Define an elastic net regression function that can 
# take different values of alpha and L1 ratios and output R squared and RMSE.
def en_R2_RMSE(alpha, l1_ratio):
    data = []
    for a in alpha:
        for r in l1_ratio:
            model = ElasticNet(alpha=a)
            model.fit(X_train, y_train)
    
            model_r2_train = model.score(X_train, y_train)
            model_r2_test = model.score(X_test, y_test)
    
            model_y_pred_train = model.predict(X_train)
            model_y_pred_test = model.predict(X_test)
            model_RMSE_train = np.sqrt(mean_squared_error(y_train, model_y_pred_train))
            model_RMSE_test = np.sqrt(mean_squared_error(y_test, model_y_pred_test))
    
            data.append(['Elastic Net', a, r, model_r2_train, model_r2_test, model_RMSE_train, model_RMSE_test])
            
    table = pd.DataFrame(data, columns = ['Model', 'Alpha', 'L1 Ratio', 'Training R2', 'Test R2', 'Training RMSE', 'Test RMSE'])
    
    return table

# %%
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
l1_ratio = [0.2, 0.4, 0.6, 0.8]
en_results = en_R2_RMSE(alpha, l1_ratio)
en_results
# Out:
#           Model     Alpha  L1 Ratio  Training R2   Test R2  Training RMSE  \
# 0   Elastic Net     0.001       0.2     0.756261  0.734043    6056.128399
# 1   Elastic Net     0.001       0.4     0.756261  0.734043    6056.128399
# 2   Elastic Net     0.001       0.6     0.756261  0.734043    6056.128399
# 3   Elastic Net     0.001       0.8     0.756261  0.734043    6056.128399
# 4   Elastic Net     0.010       0.2     0.754827  0.731078    6073.919579
# 5   Elastic Net     0.010       0.4     0.754827  0.731078    6073.919579
# 6   Elastic Net     0.010       0.6     0.754827  0.731078    6073.919579
# 7   Elastic Net     0.010       0.8     0.754827  0.731078    6073.919579
# 8   Elastic Net     0.100       0.2     0.700729  0.675363    6710.652611
# 9   Elastic Net     0.100       0.4     0.700729  0.675363    6710.652611
# 10  Elastic Net     0.100       0.6     0.700729  0.675363    6710.652611
# 11  Elastic Net     0.100       0.8     0.700729  0.675363    6710.652611
# 12  Elastic Net     1.000       0.2     0.311151  0.300776   10181.094782
# 13  Elastic Net     1.000       0.4     0.311151  0.300776   10181.094782
# 14  Elastic Net     1.000       0.6     0.311151  0.300776   10181.094782
# 15  Elastic Net     1.000       0.8     0.311151  0.300776   10181.094782
# 16  Elastic Net    10.000       0.2     0.044878  0.041447   11988.421998
# 17  Elastic Net    10.000       0.4     0.044878  0.041447   11988.421998
# 18  Elastic Net    10.000       0.6     0.044878  0.041447   11988.421998
# 19  Elastic Net    10.000       0.8     0.044878  0.041447   11988.421998
# 20  Elastic Net   100.000       0.2     0.004605  0.001986   12238.558761
# 21  Elastic Net   100.000       0.4     0.004605  0.001986   12238.558761
# 22  Elastic Net   100.000       0.6     0.004605  0.001986   12238.558761
# 23  Elastic Net   100.000       0.8     0.004605  0.001986   12238.558761
# 24  Elastic Net  1000.000       0.2     0.000389 -0.002138   12264.452484
# 25  Elastic Net  1000.000       0.4     0.000389 -0.002138   12264.452484
# 26  Elastic Net  1000.000       0.6     0.000389 -0.002138   12264.452484
# 27  Elastic Net  1000.000       0.8     0.000389 -0.002138   12264.452484
#
#        Test RMSE
# 0    5981.248036
# 1    5981.248036
# 2    5981.248036
# 3    5981.248036
# 4    6014.501211
# 5    6014.501211
# 6    6014.501211
# 7    6014.501211
# 8    6608.229914
# 9    6608.229914
# 10   6608.229914
# 11   6608.229914
# 12   9698.271540
# 13   9698.271540
# 14   9698.271540
# 15   9698.271540
# 16  11355.180975
# 17  11355.180975
# 18  11355.180975
# 19  11355.180975
# 20  11586.553806
# 21  11586.553806
# 22  11586.553806
# 23  11586.553806
# 24  11610.472336
# 25  11610.472336
# 26  11610.472336
# 27  11610.472336

# %% [markdown]
# Even the best elastic net regression isn't better than ridge and lasso regression.

# %% [markdown]
# ### Hyperparameter table

# %% [markdown]
# Below are the best models of each type.

# %%
best_results = pd.concat([linear_results.iloc[:1], ridge_results.iloc[:1], lasso_results.iloc[:1], en_results.iloc[:1]])
best_results
# Out:
#          Model  Alpha L1 Ratio  Training R2   Test R2  Training RMSE  \
# 0       Linear     NA       NA     0.756279  0.734275    6055.905613
# 0        Ridge  0.001       NA     0.756279  0.734275    6055.905614
# 0        Lasso  0.001       NA     0.756279  0.734275    6055.905613
# 0  Elastic Net  0.001      0.2     0.756261  0.734043    6056.128399
#
#      Test RMSE
# 0  5978.637219
# 0  5978.642138
# 0  5978.638781
# 0  5981.248036

# %% [markdown]
# Plain old vanilla linear regression appears to perform the best.

# %%
# Save the table for final metrics file
# %store best_results
# Out:
# Stored 'best_results' (DataFrame)
