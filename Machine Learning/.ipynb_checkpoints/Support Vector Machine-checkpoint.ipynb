# %% [markdown]
# # Machine Learning with Support Vector Machine
#
# Now I will train a regression model using support vector machine.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %%
# Bring in the data
# %store -r X_train
# %store -r X_test
# %store -r y_train
# %store -r y_test

# %% [markdown]
# ### Support Vector Regressor

# %%
# Define a support vector regressor function that can take different 
# kernel, degree, gamma, coef0, and C and output R squared and RMSE.
def svr_R2_RMSE(kernel, degree, gamma, coef0, C):
    data = []
    for k in kernel:
        for d in degree:
            for g in gamma:
                for c in coef0:
                    for small_c in C:
                        model = SVR(kernel=k, degree=d, gamma=g, coef0=c, C=small_c)
                        model.fit(X_train, y_train)
    
                        model_r2_train = model.score(X_train, y_train)
                        model_r2_test = model.score(X_test, y_test)
    
                        model_y_pred_train = model.predict(X_train)
                        model_y_pred_test = model.predict(X_test)
                        model_RMSE_train = np.sqrt(mean_squared_error(y_train, model_y_pred_train))
                        model_RMSE_test = np.sqrt(mean_squared_error(y_test, model_y_pred_test))
    
                        data.append([k, d, g, c, small_c, model_r2_train, model_r2_test, model_RMSE_train, model_RMSE_test])
            
    table = pd.DataFrame(data, columns = ['Kernel', 'Degree','Gamma','Coeficient', 'C', 'Training R2', 'Test R2', 'Training RMSE', 'Test RMSE'])
    
    return table

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
degree = [3]
gamma = ['scale']
coef0=[0]
C=[1.0]

svr_R2_RMSE(kernel, degree, gamma, coef0, C)
# Out:
#     Kernel  Degree  Gamma  Coeficient    C  Training R2   Test R2  \
# 0   linear       3  scale           0  1.0    -0.098590 -0.079234
# 1     poly       3  scale           0  1.0    -0.091238 -0.072945
# 2      rbf       3  scale           0  1.0    -0.110051 -0.090491
# 3  sigmoid       3  scale           0  1.0    -0.108943 -0.089211
#
#    Training RMSE     Test RMSE
# 0   12857.318483  12048.801222
# 1   12814.225031  12013.646196
# 2   12924.210237  12111.475306
# 3   12917.757094  12104.368521

# %% [markdown]
# The choice in kernel seems arbitrary at this point.

# %%
kernel = ['rbf']
degree = [3]
gamma = [1]
coef0=[0]
C=[0.001, 0.01, 0.1, 1.0, 10]

svr_R2_RMSE(kernel, degree, gamma, coef0, C)
# Out:
#   Kernel  Degree  Gamma  Coeficient       C  Training R2   Test R2  \
# 0    rbf       3      1           0   0.001    -0.113483 -0.093745
# 1    rbf       3      1           0   0.010    -0.113462 -0.093726
# 2    rbf       3      1           0   0.100    -0.113258 -0.093535
# 3    rbf       3      1           0   1.000    -0.111142 -0.091552
# 4    rbf       3      1           0  10.000    -0.089900 -0.071645
#
#    Training RMSE     Test RMSE
# 0   12944.173894  12129.533910
# 1   12944.055083  12129.427877
# 2   12942.867039  12128.367613
# 3   12930.559620  12117.368389
# 4   12806.366429  12006.364358

# %%
kernel = ['poly']
degree = [2,3,4]
gamma = ['scale']
coef0 = [0,1,2]
C=[1]

svr_R2_RMSE(kernel, degree, gamma, coef0, C)
# Out:
#   Kernel  Degree  Gamma  Coeficient  C  Training R2   Test R2  Training RMSE  \
# 0   poly       2  scale           0  1    -0.099704 -0.080650   12863.832512
# 1   poly       2  scale           1  1    -0.083851 -0.065198   12770.780856
# 2   poly       2  scale           2  1    -0.068042 -0.049790   12677.299724
# 3   poly       3  scale           0  1    -0.091238 -0.072945   12814.225031
# 4   poly       3  scale           1  1    -0.028645 -0.012944   12441.286803
# 5   poly       3  scale           2  1     0.074128  0.086344   11803.422526
# 6   poly       4  scale           0  1    -0.076322 -0.059224   12726.343680
# 7   poly       4  scale           1  1     0.108832  0.117104   11580.102750
# 8   poly       4  scale           2  1     0.457905  0.455633    9031.718227
#
#       Test RMSE
# 0  12056.701488
# 1  11970.194244
# 2  11883.305085
# 3  12013.646196
# 4  11672.902666
# 5  11086.064765
# 6  11936.581476
# 7  10897.850985
# 8   8557.201523

# %% [markdown]
# Support vector regressor doesn't perform very well on this dataset.
